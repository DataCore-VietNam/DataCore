# %%
from datacore import Datacore

client = Datacore()
df = client.preview("vsic")
df
# Out:
#      ID   Code                                               Name  Level  \
# 0  1001  52224  Hoạt động dịch vụ hỗ trợ liên quan đến vận tải...      5
# 1  1002   5223  Hoạt động dịch vụ hỗ trợ trực tiếp cho vận tải...      4
# 2  1003  52231                              Dịch vụ điều hành bay      5
# 3  1004  52232        Dịch vụ điều hành hoạt động cảng hàng không      5
# 4  1005  52239  Hoạt động dịch vụ hỗ trợ liên quan đến vận tải...      5
# 5  1006   5224                                   Bốc xếp hàng hóa      4
# 6  1007  52241                      Bốc xếp hàng hóa ga đường sắt      5
# 7  1008  52242                          Bốc xếp hàng hóa đường bộ      5
# 8  1009  52243                         Bốc xếp hàng hóa cảng biển      5
# 9  1010  52244                         Bốc xếp hàng hóa cảng sông      5
#
#   Parent_code                    Full_path  year
# 0        5222  H > 52 > 522 > 5222 > 52224  2018
# 1         522          H > 52 > 522 > 5223  2018
# ...
